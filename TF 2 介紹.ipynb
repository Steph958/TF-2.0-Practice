# %%
# 上傳自有資料到Colab
from google.colab import files
uploaded = files.upload()

# %%
# 從Google Drive匯入資料到Colab
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# 檢查Google Drive是否成功掛載
# !ls /content/drive/'My Drive'
# Out:
# '2020 高雄酒吧地圖 Kaohsiung Bar的副本.gmap'
# 'Colab Notebooks'
# 'Hannah Arendt_the debate on the course.mp4'

# %%
# 讀取Kaggle上的資料集到Colab
# !pip install -q kaggle==1.5.6

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0be22add-2726-45f4-9b09-d4cecd29c9a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0be22add-2726-45f4-9b09-d4cecd29c9a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"hauhsiunglee","key":"b0fac84ff4be293eddc8d4d3f6973c1a"}'}

# %%
#建立一個資料夾把token放入，並給予其權限
! mkdir ~/.kaggle
! mv kaggle.json ~/.kaggle/
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
#列出所有可供下載的資料集以及其時間大小下載次數等
# !kaggle datasets list  --min-size 10
# Out:
# usage: kaggle [-h] [-v] {competitions,c,datasets,d,kernels,k,config} ...
# kaggle: error: unrecognized arguments: --min-size 10

# %%
#從kaggle下載檔案
# !kaggle competitions download -c dogs-vs-cats
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# 403 - Forbidden
